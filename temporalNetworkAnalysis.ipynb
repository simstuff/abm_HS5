# %%
import pandas as pd
import networkx as nx
import pickle
import teneto as tnet
import os
# Out:
# /home/niklas/.local/lib/python3.11/site-packages/nilearn/input_data/__init__.py:23: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
path="/home/niklas/Documents/Studium_Uni_Bamberg/Semester4/PWM-PT-HS5/abm_HS5/graphs"
files=os.listdir(path)
  
files=sorted(files)
network_df=None
for f in files:
    file_path=os.path.join(path,f)
    tmp=pd.read_csv(file_path)
    if network_df is None:
        network_df=tmp
    network_df=pd.concat([network_df,tmp],ignore_index=True)
network_df
# Out:
#       Unnamed: 0  source  target  weight  info  step
# 0              0       0       4     0.0   0.0     0
# 1              1       1      10     0.0   0.0     0
# 2              2       2      12     0.0   0.0     0
# 3              3       3       6     0.0   0.0     0
# 4              4       4       0     0.0   0.0     0
# ...          ...     ...     ...     ...   ...   ...
# 6113          95      13      11     0.0   0.0     9
# 6114          96      13       3     0.0   0.0     9
# 6115          97      13       4     0.0   0.0     9
# 6116          98      13       1     0.0   0.0     9
# 6117          99      13       2     0.0   0.0     9
#
# [6118 rows x 6 columns]

# %%
time_df=network_df[["source","target","step","weight"]]
time_df=time_df.rename(columns={"source":'i',"target":'j',"step":'t'})

# %%
temporal_net=tnet.TemporalNetwork(from_df=time_df)

# %%
temporal_net.network
# Out:
#        i   j  t
# 0      0   4  0
# 1      1  10  0
# 2      2  12  0
# 3      3   6  0
# 4      5  11  0
# ...   ..  .. ..
# 3047   9  13  9
# 3048   9  11  9
# 3049   9  12  9
# 3050  11  13  9
# 3051  12  13  9
#
# [3052 rows x 3 columns]

# %%
df1=make_edge_df(G)

# %%
for source, target, attribute in G.edges(data=True):
    print(attribute.items())
# Out:
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# dict_items([])
# ...
